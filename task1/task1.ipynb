# %% [markdown]
# 1.heading
# # ENGLISH

# %% [markdown]
# ## MATHS

# %% [markdown]
# ### MARATHI

# %% [markdown]
# ## 2. bullet points
# * item1
# * item2
# * item3

# %% [markdown]
# # 3.horizontal line
# ***
# -------
# ________

# %% [markdown]
# # 4 bold
# **this is python**

# %% [markdown]
#  # 5. italic
# *this is italic*

# %% [markdown]
# # 6.bold and italic
# ***this is markdown tutorial***

# %% [markdown]
# # 7. number list
# 1. this is python
# 2. this is markdown tutorial

# %% [markdown]
# # 8.strikethrouh
# ~this is markdown tutorial~

# %% [markdown]
# # 9. codeblock
# this is `markdown` tutorial

# %% [markdown]
# # 10. create table
# | name | age |
# |-------|------|
# |rosy   | 23   |
# |jocky  | 31   |

# %% [markdown]
# # 11. task list
# - [x] task1
# - [x] task2
# - [x] task3

# %% [markdown]
# # 12. text colour
# <font color='red'> this is markdown tutorial</font>.

# %% [markdown]
# # 13. mathematical symbol
# $ a^2 + 3ab + b^3 $

# %% [markdown]
# $\sum$

# %% [markdown]
# # 14. insert image
# $[](![WhatsApp Image 2024-09-04 at 09.11.13_bd853f76.jpg](attachment:3eb76628-3c5f-41c1-bd9d-c335c81ddec8.jpg)

# %% [markdown]
# # 15.External link
# __[link to mongodb](https://t.me/c/2176248200/245)__
